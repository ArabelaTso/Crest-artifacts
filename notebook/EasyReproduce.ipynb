# %% [markdown]
# # Example for easy reproduction

# %% [markdown]
# **Important notes before running the script**
# - To run the script, please make sure you have set up all the requirements in README.md - Prerequisition
# - Please make sure you fill in the directory of Standford core nlp in `crest.py` (Highlighted by TODO)
# - Please launch Stanford Core NLP sever at Port 9001 and make sure the port number is not occupied

# %% [markdown]
# ## 1. Read data from CoNLL12

# %%
import os
import sys
import random

# WARNING! Before running the script, please make sure you have filled in the 'TODO' in crest.py
from main import *
from utils import readCoNLL12

# %%
oriSentencePairs = readCoNLL12()

sample_num = 2  # change this number to use more source inputs
oriSentencePairs = random.sample(oriSentencePairs, k=sample_num)

print("Sampled {} sentences as source inputs.".format(sample_num))
# Out:
# Read 2894 lines from conll12/dev.english.v4_gold_conll.sen.json.
# Sampled 2 sentences as source inputs.

# %% [markdown]
# ## 2. Test generation

# %% [markdown]
# ### Preparation -  Make temporary directory for output

# %%
OutputDir = '../TempOutput'
os.makedirs(OutputDir, exist_ok=True)

# %% [markdown]
# ### Preparation - Setup nlp pipeline

# %%
# load nlp
nlp = setup_nlp_pipeline()
# Out:
# Some weights of the model checkpoint at nreimers/mMiniLMv2-L12-H384-distilled-from-XLMR-Large were not used when initializing XLMRobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing XLMRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaModel were not initialized from the model checkpoint at nreimers/mMiniLMv2-L12-H384-distilled-from-XLMR-Large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Generation - Crest

# %%
genMethodName = 'Crest'
output_tsv_fn = os.path.join(OutputDir, '{}.tsv'.format(genMethodName))
Coref_testing(nlp, oriSentencePairs, genMethodName=genMethodName, output_fn=output_tsv_fn)
# Out:
# <Pair 0>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, heedlessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> heedlessly
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 1>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, cautiously wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> cautiously
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 2>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, incautiously wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> incautiously
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 3>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carefully wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> carefully
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 4>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, rakishly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> rakishly
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 5>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, raffishly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: carelessly -> raffishly
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 6>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly roll their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: wheel -> roll
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[16, 16], [23, 23]]]
# - Cluster 1: their, their
# [Bug found!] Inconsistent!
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 33.33 | F1: 50.00
# ====================
#
# <Pair 7>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly pedal their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: wheel -> pedal
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[16, 16], [23, 23]]]
# - Cluster 1: their, their
# [Bug found!] Inconsistent!
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 33.33 | F1: 50.00
# ====================
#
# <Pair 8>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the wide streets, their minds elsewhere, thinking of youthful fun or romance.
# Replace: narrow -> wide
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 9>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of young fun or romance.
# Replace: youthful -> young
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 10>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of vernal fun or romance.
# Replace: youthful -> vernal
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 11>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful playfulness or romance.
# Replace: fun -> playfulness
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 12>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful play or romance.
# Replace: fun -> play
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 13>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful merriment or romance.
# Replace: fun -> merriment
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 14>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful sport or romance.
# Replace: fun -> sport
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 15>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or Romance.
# Replace: romance -> Romance
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 16>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romanticism.
# Replace: romance -> romanticism
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 17>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials allege they never received it.
# Replace: say -> allege
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 18>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials enjoin they never received it.
# Replace: say -> enjoin
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 19>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials tell they never received it.
# Replace: say -> tell
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 20>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials articulate they never received it.
# Replace: say -> articulate
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 21>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials read they never received it.
# Replace: say -> read
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 22>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials enounce they never received it.
# Replace: say -> enounce
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 23>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials suppose they never received it.
# Replace: say -> suppose
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 24>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they ever received it.
# Replace: never -> ever
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 25>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never meet it.
# Replace: received -> meet
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
#
#
# ====================
# Summary:
# Number of origin sentence: 2 | Failed: 0
# Number of generated pairs: 26 | Failed: 11

# %% [markdown]
# ### SIT

# %%
genMethodName = 'SIT'
output_tsv_fn = os.path.join(OutputDir, '{}.tsv'.format(genMethodName))
Coref_testing(nlp, oriSentencePairs, genMethodName=genMethodName, output_fn=output_tsv_fn)
# Out:
# skip a sentence. unknown token is 'carelessly'
#
# <Pair 0>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA others say they never received it.
# Replace: officials -> others
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 1>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA people say they never received it.
# Replace: officials -> people
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
#
#
# ====================
# Summary:
# Number of origin sentence: 2 | Failed: 0
# Number of generated pairs: 2 | Failed: 2

# %% [markdown]
# ### PatInv

# %%
genMethodName = 'PatInv'
output_tsv_fn = os.path.join(OutputDir, '{}.tsv'.format(genMethodName))
Coref_testing(nlp, oriSentencePairs, genMethodName=genMethodName, output_fn=output_tsv_fn)
# Out:
# skip a sentence. unknown token is 'carelessly'
# skip a sentence. unknown token is 'pirate'
# skip a sentence. unknown token is 'germans'
# skip a sentence. unknown token is 'italians'
# skip a sentence. unknown token is 'their'
#
# <Pair 0>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA people say they never received it.
# Replace: officials -> people
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 1>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA things say they never received it.
# Replace: officials -> things
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 2>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA men say they never received it.
# Replace: officials -> men
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 1], [3, 3]]]
# - Cluster 1: CIA men, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 3>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA friends say they never received it.
# Replace: officials -> friends
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 4>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA guys say they never received it.
# Replace: officials -> guys
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 1], [3, 3]]]
# - Cluster 1: CIA guys, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 5>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA vampires say they never received it.
# Replace: officials -> vampires
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 1], [3, 3]]]
# - Cluster 1: CIA vampires, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 6>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA girls say they never received it.
# Replace: officials -> girls
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 7>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials believe they never received it.
# Replace: say -> believe
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 8>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials knew they never received it.
# Replace: say -> knew
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 9>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials know they never received it.
# Replace: say -> know
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 10>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials believed they never received it.
# Replace: say -> believed
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 11>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials realize they never received it.
# Replace: say -> realize
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 12>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials think they never received it.
# Replace: say -> think
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 13>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials thought they never received it.
# Replace: say -> thought
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 14>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials realized they never received it.
# Replace: say -> realized
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 15>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they also received it.
# Replace: never -> also
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 16>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they actually received it.
# Replace: never -> actually
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 17>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they still received it.
# Replace: never -> still
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 18>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they already received it.
# Replace: never -> already
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 19>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they officially received it.
# Replace: never -> officially
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 20>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they even received it.
# Replace: never -> even
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 21>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they finally received it.
# Replace: never -> finally
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 22>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they simply received it.
# Replace: never -> simply
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 23>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they originally received it.
# Replace: never -> originally
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 24>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they first received it.
# Replace: never -> first
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 25>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they really received it.
# Replace: never -> really
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 26>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they immediately received it.
# Replace: never -> immediately
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 27>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they later received it.
# Replace: never -> later
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 28>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they previously received it.
# Replace: never -> previously
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 29>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they however received it.
# Replace: never -> however
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 30>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they soon received it.
# Replace: never -> soon
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 31>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they apparently received it.
# Replace: never -> apparently
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 32>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they eventually received it.
# Replace: never -> eventually
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 33>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they probably received it.
# Replace: never -> probably
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 34>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they merely received it.
# Replace: never -> merely
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 35>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never found it.
# Replace: received -> found
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 36>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never find it.
# Replace: received -> find
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 37>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never believe it.
# Replace: received -> believe
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 38>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never finished it.
# Replace: received -> finished
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 39>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never watch it.
# Replace: received -> watch
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 40>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never know it.
# Replace: received -> know
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 41>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never finish it.
# Replace: received -> finish
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 42>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never use it.
# Replace: received -> use
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 43>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never eat it.
# Replace: received -> eat
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 44>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never saw it.
# Replace: received -> saw
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 45>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never move it.
# Replace: received -> move
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 46>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never completed it.
# Replace: received -> completed
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 47>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never want it.
# Replace: received -> want
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 48>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never leave it.
# Replace: received -> leave
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 49>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never hit it.
# Replace: received -> hit
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 50>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never play it.
# Replace: received -> play
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 51>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never built it.
# Replace: received -> built
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 52>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never knew it.
# Replace: received -> knew
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 53>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never studied it.
# Replace: received -> studied
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 54>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never bring it.
# Replace: received -> bring
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 55>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never put it.
# Replace: received -> put
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 56>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never ate it.
# Replace: received -> ate
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 57>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never remember it.
# Replace: received -> remember
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 58>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never cut it.
# Replace: received -> cut
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 59>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never bought it.
# Replace: received -> bought
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 60>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never discovered it.
# Replace: received -> discovered
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 61>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never consider it.
# Replace: received -> consider
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 62>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never return it.
# Replace: received -> return
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 63>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never show it.
# Replace: received -> show
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 64>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials say they never started it.
# Replace: received -> started
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
#
#
# ====================
# Summary:
# Number of origin sentence: 2 | Failed: 0
# Number of generated pairs: 65 | Failed: 65

# %% [markdown]
# ### CAT

# %%
genMethodName = 'CAT'
output_tsv_fn = os.path.join(OutputDir, '{}.tsv'.format(genMethodName))
Coref_testing(nlp, oriSentencePairs, genMethodName=genMethodName, output_fn=output_tsv_fn)
# Out:
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <Pair 5>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA sources say they never received it .
# Replace: officials -> sources
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 6>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials claim they never received it .
# Replace: say -> claim
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 7>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials said they never received it .
# Replace: say -> said
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 8>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials claimed they never received it .
# Replace: say -> claimed
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 9>
# Origin  :  CIA officials say they never received it.
# Generate:  The officials say they never received it .
# Replace: CIA -> The
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 1], [3, 3]]]
# - Cluster 1: The officials, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
#
#
# ====================
# Summary:
# Number of origin sentence: 2 | Failed: 0
# Number of generated pairs: 10 | Failed: 5
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <Pair 0>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students , who have enough money to keep several streets of shops going , carelessly wheel their motorcycles along the narrow streets , their minds elsewhere , thinking of youthful fun or romance .
# Replace: through -> along
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students , who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 1>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students , who have enough money to keep several streets of shops going , carelessly wheel their motorcycles down the narrow streets , their minds elsewhere , thinking of youthful fun or romance .
# Replace: through -> down
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students , who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 2>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students , who have enough money to keep several streets of shops going , aimlessly wheel their motorcycles through the narrow streets , their minds elsewhere , thinking of youthful fun or romance .
# Replace: care -> aim
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students , who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 3>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  Students , who have enough money to keep several streets of shops going , mindlessly wheel their motorcycles through the narrow streets , their minds elsewhere , thinking of youthful fun or romance .
# Replace: care -> mind
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students , who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
#
# <Pair 4>
# Origin  :  Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.
# Generate:  People , who have enough money to keep several streets of shops going , carelessly wheel their motorcycles through the narrow streets , their minds elsewhere , thinking of youthful fun or romance .
# Replace: Students -> People
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: Students, who have enough money to keep several streets of shops going, their, their
#
# > Generated sentence's Coref:
# [[[0, 12], [16, 16], [23, 23]]]
# - Cluster 1: People , who have enough money to keep several streets of shops going, their, their
# [Pass]
# Origin  : Precision: 33.33 | Recall: 33.33 | F1: 33.33
# Generate  : Precision: 100.00 | Recall: 100.00 | F1: 100.00
# ====================
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <Pair 5>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA sources say they never received it .
# Replace: officials -> sources
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 0], [3, 3]]]
# - Cluster 1: CIA, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 6>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials claim they never received it .
# Replace: say -> claim
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 7>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials said they never received it .
# Replace: say -> said
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 8>
# Origin  :  CIA officials say they never received it.
# Generate:  CIA officials claimed they never received it .
# Replace: say -> claimed
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# []
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
# <Pair 9>
# Origin  :  CIA officials say they never received it.
# Generate:  The officials say they never received it .
# Replace: CIA -> The
# ====================
# oriConsistent False
# > Origin sentence's Coref:
# []
#
# > Generated sentence's Coref:
# [[[0, 1], [3, 3]]]
# - Cluster 1: The officials, they
# [Bug found!] Inconsistent!
# Origin  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# Generate  : Precision: 0.00 | Recall: 0.00 | F1: 0.00
# ====================
#
#
#
# ====================
# Summary:
# Number of origin sentence: 2 | Failed: 0
# Number of generated pairs: 10 | Failed: 5

# %% [markdown]
# ### 3. Calculate semantic similarity and naturalness

# %%
from codebook.Eval_Sim_Nat import AeonScorer

# %%
scorer = AeonScorer(batch_size=8, masked_lm='bert-base-uncased', embed_lm='princeton-nlp/sup-simcse-bert-base-uncased', verbose=False)

source = 'Students, who have enough money to keep several streets of shops going, carelessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.'
follow = 'Students, who have enough money to keep several streets of shops going, heedlessly wheel their motorcycles through the narrow streets, their minds elsewhere, thinking of youthful fun or romance.'

result = scorer.compute(source, follow)

for sim in ['semSim', 'natDiff']:
    print('{}: {}'.format(sim, result[sim][0]))
# Out:
# 2022-09-05 15:25:58 [INFO] Using cpu
# 2022-09-05 15:25:58 [INFO] Using batch size: 8
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2022-09-05 15:26:17 [INFO] Masked LM model: bert-base-uncased
# 2022-09-05 15:26:31 [INFO] Embedding model: princeton-nlp/sup-simcse-bert-base-uncased
# 2022-09-05 15:26:31 [INFO] Calculating scores
#
#
# 2022-09-05 15:26:39 [INFO] Finish text number 0
# semSim: 0.9418442249298096
# natDiff: 0.021671870750692268
